# %% [markdown]
# # TRY - EXCEPT - FINALLY

# %%
try:
  a = float(input("Bölünen : "))
  b = float(input("Bölen : "))
  print(a/b)
except ValueError:
  print("Lütfen geçerli bir sayı giriniz.")
except ZeroDivisionError:
  print("Bölen 0 olursa sonsuza gidicektir. Matematiksel olarak bir şeyi temsil etmez.")
except KeyboardInterrupt:
  print("Çıkış yapılıyor.")
except:
  print("Bu bir hatadır.")
finally:
  print("Tech Istanbul Bootcamp")
# Out:
# Çıkış yapılıyor.

# %%
sayi = int(input("Sayı giriniz : "))

if sayi == 3:
  raise Exception("Asla 3 kullanmayın.")
  print("Kanıt")
# Out:
# Sayı giriniz : 3
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_1536/1788801843.py in <cell line: 0>()
#       2
#       3 if sayi == 3:
# ----> 4   raise Exception("Asla 3 kullanmayın.")
#       5   print("Kanıt")
#
# Exception: Asla 3 kullanmayın.

# %%
a = "Ecrin"

print(a[1:5])
# Out:
# crin

# %%
b = "Tech İstanbul Veri Bilimi Bootcamp"

print(b)
print(b.replace(" ", ""))
# Out:
# Tech İstanbul Veri Bilimi Bootcamp
# TechİstanbulVeriBilimiBootcamp

# %%
c = """
Tech Istanbul, İstanbul Büyükşehir Belediyesi'ne (İBB) bağlı bir girişimcilik ve teknoloji merkezidir. Teknoloji odaklı girişimlere destek olmak amacıyla ön kuluçka, büyüme (growth) programları ve ortak çalışma alanları sunar. Ön Kuluçka ve Hızlandırma: Yeni fikirlerin ve erken aşama girişimlerin gelişmesini destekler. Growth Programları: İleri aşamadki girişimlerin büyümesine ve ölçeklenmesine yardımcı olur. PoC (Kavram Kanıtlama) Fırsatları: Girişimlerin ürünlerini İBB ve iştirakleriyle birlikte test etmesini sağlar.

"""

print(c)
c = c.replace("\n", "")
liste = c.split(".")
print(liste)
# Out:
# Tech Istanbul, İstanbul Büyükşehir Belediyesi'ne (İBB) bağlı bir girişimcilik ve teknoloji merkezidir. Teknoloji odaklı girişimlere destek olmak amacıyla ön kuluçka, büyüme (growth) programları ve ortak çalışma alanları sunar. Ön Kuluçka ve Hızlandırma: Yeni fikirlerin ve erken aşama girişimlerin gelişmesini destekler. Growth Programları: İleri aşamadki girişimlerin büyümesine ve ölçeklenmesine yardımcı olur. PoC (Kavram Kanıtlama) Fırsatları: Girişimlerin ürünlerini İBB ve iştirakleriyle birlikte test etmesini sağlar.
#
#
# ...

# %% [markdown]
# # Matematiksel Fonksiyonlar

# %%
a = -56
print(abs(a))
# Out:
# 56

# %%
a = 99
b = 32

c = int(a/b)
d = a/b - c
d = int(d*b)
print(c)
print(d)

print(divmod(a,b))
# Out:
# 3
# 3
# (3, 3)

# %%
a = [10,2,6,22,40,30,100,6]
en_yuksek_deger = 0
for maks in a:
    if en_yuksek_deger < maks:
        en_yuksek_deger = maks

print(en_yuksek_deger)
print(max(a))
print(min(a))
# Out:
# 100
# 100
# 2

# %%
toplam = 0
for topla in a:
  toplam += topla
print(toplam)
print(sum(a))
# Out:
# 216
# 216

# %%
a = 1
b = 3
c = a/b
d = 2.57777
print(round(c,3))
print(round(d,3))
# Out:
# 0.333
# 2.578

# %% [markdown]
# # Dosya İşlemleri

# %%
# !ls
# Out:
# deneme2.txt  deneme.txt  sample_data

# %%
dosya = open("deneme.txt","r", encoding='utf-8')

veri = dosya.read()
dosya.close()
print(veri)
# Out:
# Ecrin
# Kaya
# Tech Istanbul
# Bootcamp
# Hayat sevince güzel

# %%
dosya = open("deneme2.txt","r", encoding='utf-8')

veri = dosya.read()
dosya.close()
print(veri)
# Out:
# Hayat sevince güzel

# %%
dosya = open("deneme2.txt","a")
eklenecek_veri = "\nHayat sevince güzel"
dosya.write(eklenecek_veri)
dosya.close()

# %%
dosya = open("deneme2.txt","w")
dosya.write(eklenecek_veri)
dosya.close()

# %%
dosya = open("deneme2.txt","w")
dosya.write(eklenecek_veri)
dosya.close()

# %%
dosya = open("deneme.txt","r", encoding='utf-8')

veri2 = dosya.readlines()
dosya.close()
print(veri2)
# Out:
# ['Ecrin\n', 'Kaya\n', 'Tech Istanbul\n', 'Bootcamp\n', 'Hayat sevince güzel']

# %%
a = input("Silmek istediğiniz satırı giriniz : ")
a += "\n"
dosya = open("deneme2.txt","w")
for veri in veri2:
    if a==veri:
        pass
    else:
        dosya.write(veri)
dosya.close()
# Out:
# Silmek istediğiniz satırı giriniz : Istanbul

# %% [markdown]
# # Kütüphane

# %%
import os

# %%
os.system("pwd")
# Out:
# 0

# %%
from time import sleep as uyku


print("Başladı")
uyku(3)
print("Bitti")
# Out:
# Başladı
# Bitti
